# %%
def polyfit(x, y, degree):
    results = {}

    coeffs = numpy.polyfit(x, y, degree)
     # Polynomial Coefficients
    results['polynomial'] = coeffs.tolist()

    correlation = numpy.corrcoef(x, y)[0,1]
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
csv_file='Documents/Research/K3L3HD 03062020.csv'
data = pd.read_csv(csv_file)
data
# Out:
#      Wavelength (nm)     50_50    50_100    50_150    50_200    50_250  \
# 0         800.005859 -0.000285 -0.004529  0.000627 -0.003305 -0.002132
# 1         794.991394  0.001245 -0.003173  0.001140 -0.001715  0.000264
# 2         790.001831  0.000060 -0.002806 -0.000474 -0.002994 -0.000517
# 3         785.002625  0.001245 -0.002650  0.001567 -0.002550 -0.000029
# 4         779.993713  0.000481 -0.002808  0.001084 -0.002140  0.000738
# ..               ...       ...       ...       ...       ...       ...
# 104       279.986328  0.128879  0.099361  0.121015  0.143943  0.132893
# 105       274.988098  0.138551  0.106543  0.128902  0.152980  0.141434
# 106       269.987213  0.146365  0.113007  0.136024  0.161336  0.149249
# 107       264.983734  0.153122  0.117451  0.141787  0.168718  0.156760
# 108       260.017059  0.156558  0.120840  0.146041  0.173201  0.160325
#
#        50_300    50_350    50_400    50_450    50_500      50_0  Unnamed: 12  \
# ...

# %%
Wavelength = data["Wavelength (nm)"]
Zero = data["50_0"]
One = data["50_50"]
Two = data["50_100"]
Thr = data["50_150"]
Four =  data["50_200"]
Five = data["50_250"]
Six = data["50_300"]
Sev = data["50_350"]
Eig = data["50_400"]
Nin = data["50_450"]
Ten = data["50_500"]

# %%
w= Wavelength
q = Two
e = Thr
r = Four
t = Five
y = Six
u = Sev
i = Eig
o = Nin
p = Ten
plt.scatter(w,q)
plt.scatter(w,e)
plt.scatter(w,r)
plt.scatter(w,t)
plt.scatter(w,y)
plt.scatter(w,u)
plt.scatter(w,i)
plt.scatter(w,o)
plt.scatter(w,p)

# %%
x = np.array([0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500])
y = np.array([max(Zero), max(One), max(Two), max(Thr), max(Four), max(Five), max(Six), max(Sev), max(Eig), max(Nin), max(Ten)])
plt.scatter(x,y)

# %%
z= max(Zero)
z
# Out:
# 0.348809689
